# %%
import firebase_admin
from firebase_admin import credentials

cred = credentials.Certificate("serviceAccountKey.json")
firebase_admin.initialize_app(cred,{'databaseURL': "https://faceattendanceproject-45968-default-rtdb.firebaseio.com/"})

# %%
from firebase_admin import db

ref = db.reference('Students')

data = {
    "S1":
        {
            "name": "Emly Blunt",
            "major": "Acting",
            "starting_year": 2020,
            "total_attendance": 12,
            "standing": "B",
            "year": 4,
            "last_attendance_time": "2022-12-11 00:54:34"
        },
    "S2":
        {
            "name": "Elon Musk",
            "major": "Physics",
            "starting_year": 2021,
            "total_attendance": 7,
            "standing": "G",
            "year": 3,
            "last_attendance_time": "2022-12-11 00:54:34"
        },
    "S3":
        {
            "name": "Ana de Armas",
            "major": "Acting",
            "starting_year": 2023,
            "total_attendance": 7,
            "standing": "G",
            "year": 1,
            "last_attendance_time": "2022-12-11 00:54:34"
        },
    "S4":
        {
            "name": "Sunny Leone",
            "major": "Nursing",
            "starting_year": 2020,
            "total_attendance": 7,
            "standing": "G",
            "year": 4,
            "last_attendance_time": "2022-12-11 00:54:34"
        },
    "S5":
        {
            "name": "Lisa",
            "major": "Dancing",
            "starting_year": 2022,
            "total_attendance": 7,
            "standing": "G",
            "year": 2,
            "last_attendance_time": "2022-12-11 00:54:34"
        },
    "S6":
        {
            "name": "Narendra Modi",
            "major": "Politics",
            "starting_year": 2020,
            "total_attendance": 8,
            "standing": "A",
            "year": 4,
            "last_attendance_time": "2022-12-11 00:54:34"
        },
    "S7":
        {
            "name": "Olivia Rodrigo",
            "major": "Singing",
            "starting_year": 2022,
            "total_attendance": 4,
            "standing": "B",
            "year": 2,
            "last_attendance_time": "2022-12-11 00:54:34"
        },
    "S8":
        {
            "name": "SRK",
            "major": "Acting",
            "starting_year": 2020,
            "total_attendance": 9,
            "standing": "B",
            "year": 4,
            "last_attendance_time": "2022-12-11 00:54:34"
        },
    "S9":
        {
            "name": "Rose",
            "major": "Singing",
            "starting_year": 2023,
            "total_attendance": 11,
            "standing": "A",
            "year": 1,
            "last_attendance_time": "2022-12-11 00:54:34"
        }

}

for key, value in data.items():
    ref.child(key).set(value)
